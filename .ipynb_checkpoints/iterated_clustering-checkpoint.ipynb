# %%
# Dependencies
import json
import requests 
from pprint import pprint
import pandas as pd
from pandas import json_normalize
import urllib
import psycopg2
import sqlalchemy
from sqlalchemy import create_engine
from datetime import datetime, date
import schedule 
import time

# %%
# Specify the URL
url = "https://gbfs.citibikenyc.com/gbfs/es/station_status.json"

# Make request and store response
response = requests.get(url)

# Print status code
print(response.status_code)
# Out:
# 200

# %%
r = requests.get('https://gbfs.citibikenyc.com/gbfs/en/station_status.json')
df = json_normalize(r.json()['data']['stations'])
df.head()
# Out:
#   legacy_id  num_bikes_disabled  is_renting  is_returning  \
# 0        72                   2           1             1
# 1        79                   0           1             1
# 2        82                   3           1             1
# 3        83                   0           1             1
# 4       116                   1           1             1
#
#    num_bikes_available station_id  is_installed  last_reported station_status  \
# 0                    1         72             1     1596483097         active
# 1                   27         79             1     1596482971         active
# 2                   23         82             1     1596481766         active
# 3                   32         83             1     1596481609         active
# 4                    6        116             1     1596482895         active
#
#    num_docks_disabled  num_ebikes_available  eightd_has_available_keys  \
# 0                   0                     0                      False
# 1                   0                     0                      False
# 2                   0                     0                      False
# 3                   0                     0                      False
# 4                   0                     0                      False
#
#    num_docks_available
# 0                   52
# 1                    6
# 2                    1
# 3                   30
# 4                   43

# %%
df2 = df.rename(columns={"num_bikes_available":"bikes_available","num_bikes_disabled":"bikes_disabled","num_docks_available":"docks_available","num_docks_disabled":"docks_disabled","last_reported":"time_reported"})

# %%
df2.head()
# Out:
#   legacy_id  bikes_disabled  is_renting  is_returning  bikes_available  \
# 0        72               2           1             1                1
# 1        79               0           1             1               27
# 2        82               3           1             1               23
# 3        83               0           1             1               32
# 4       116               1           1             1                6
#
#   station_id  is_installed  time_reported station_status  docks_disabled  \
# 0         72             1     1596483097         active               0
# 1         79             1     1596482971         active               0
# 2         82             1     1596481766         active               0
# 3         83             1     1596481609         active               0
# 4        116             1     1596482895         active               0
#
#    num_ebikes_available  eightd_has_available_keys  docks_available
# 0                     0                      False               52
# 1                     0                      False                6
# 2                     0                      False                1
# 3                     0                      False               30
# 4                     0                      False               43

# %%
bike_df = df2[["station_id","bikes_available","bikes_disabled","docks_available","docks_disabled","time_reported"]]

# %%
bike_df.head()
# Out:
#   station_id  bikes_available  bikes_disabled  docks_available  \
# 0         72                1               2               52
# 1         79               27               0                6
# 2         82               23               3                1
# 3         83               32               0               30
# 4        116                6               1               43
#
#    docks_disabled  time_reported
# 0               0     1596483097
# 1               0     1596482971
# 2               0     1596481766
# 3               0     1596481609
# 4               0     1596482895

# %%
last_reported = datetime.fromtimestamp(bike_df.loc[0,"time_reported"])

# %%
last_reported
# Out:
# datetime.datetime(2020, 8, 3, 12, 31, 37)

# %%
def epoch_to_readable(xepoch):
    
    return datetime.fromtimestamp(xepoch)

bike_df['time_reported'] = bike_df.apply(lambda x: epoch_to_readable(x['time_reported']), axis = 1 )
# Out:
# <ipython-input-10-5919d25c1233>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bike_df['time_reported'] = bike_df.apply(lambda x: epoch_to_readable(x['time_reported']), axis = 1 )

# %%
bike_df.head()
# Out:
#   station_id  bikes_available  bikes_disabled  docks_available  \
# 0         72                1               2               52
# 1         79               27               0                6
# 2         82               23               3                1
# 3         83               32               0               30
# 4        116                6               1               43
#
#    docks_disabled       time_reported
# 0               0 2020-08-03 12:31:37
# 1               0 2020-08-03 12:29:31
# 2               0 2020-08-03 12:09:26
# 3               0 2020-08-03 12:06:49
# 4               0 2020-08-03 12:28:15

# %%
db_connection_string = "postgres:jaigurudev@localhost:5432/FinalProject"
engine = create_engine(f'postgresql://{db_connection_string}')

# %%
engine.table_names()
# Out:
# ['bikes']
